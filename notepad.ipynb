# %%
import requests, json
#r = requests.post('http://armory.warmane.com/character/Frejr/Lordaeron/achievements', json={"category": "14923"})
#r.status_code
#r.json()

url = "http://armory.warmane.com/character/Frejr/Lordaeron/achievements"
data = {'category': '14923'}
headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}
r = requests.post(url, data=json.dumps(data), headers=headers)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" class="active">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="csrf-token" content="YTk3MTMwMjg2NjNlYzQxMjExYzgyZWE3YmMxZDk5MzY=" />
# <meta name="robots" content="noodp, noydir">
# <meta name="Description" content="Private Server Community." />
# <meta name="Keywords" content="Warmane, WoW, World of Warcraft, Warcraft, Private Server, Private WoW Server, WoW Server, Private WoW Server, wow private server, wow server, wotlk server, cataclysm private server, wow cata server, best free private server, largest private server, wotlk private server, blizzlike server, mists of pandaria, mop, cataclysm, cata, anti-cheat, sentinel anti-cheat, warden" />
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon" />
# <title>Warmane Armory | Character Frejr @ Lordaeron</title>
# <link rel="stylesheet" href="/themes/warmane/stylesheets/global.css?v=1587707545">
# ...
